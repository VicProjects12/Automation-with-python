# %%
# Comparisons:
# Equal:            ==
# Not Equal:        !=
# Greater Than:     >
# Less Than:        <
# Greater or Equal: >=
# Less or Equal:    <=
# Object Identity:  is

# %%
if False:
    print('Conditional was True')

# %%
language = 'Python'

if language == 'Python':
    print('Conditional was True')
# Out:
# Conditional was True

# %%
language = 'Python'

if language == 'Python':
    print('Language is Python')
else:
    print('No match')
# Out:
# Language is Python

# %%
language = 'Java'

if language == 'Python':
    print('Language is Python')
else:
    print('No match')
# Out:
# No match

# %%
language = 'Java'

if language == 'Python':
    print('Language is Python')
elif language == 'Java':
    print('Language is Java')
else:
    print('No match')
# Out:
# Language is Java

# %%
language = 'Java'

if language == 'Python':
    print('Language is Python')
elif language == 'Java':
    print('Language is Java')
elif language == 'Javascripts':
    print('language is Javascripts')
else:
    print('No match')
# Out:
# Language is Java

# %%
# And
# or
# Not

# %%
user = 'Admin'
logged_in = False

if user == 'Admin' and logged_in:
    print('Admin Page')
else:
    print('Bad Creds')
# Out:
# Bad Creds

# %%
user = 'Admin'
logged_in = False

if user == 'Admin' or logged_in: # One is true or the other
    print('Admin Page')
else:
    print('Bad Creds')
# Out:
# Admin Page

# %%
user = 'Admin'
logged_in = False

if not logged_in:  # True
    print('Please Log in')
else:
    print('Welcome')
# Out:
# Please Log in

# %%
a = [1, 2, 3]
b = [1, 2, 3]

print(id(a))
print(id(b))
#print(a == b)
print(a is b)
# Out:
# 1714639890432
# 1714639511488
# False

# %%
a = [1, 2, 3]
b = a

print(id(a))
print(id(b))
#print(a == b)
print(a is b)
print(a == b)
# Out:
# 1714639828928
# 1714639828928
# True
# True

# %%
# False Values:
    # False
    # None
    # Zero of any numeric type
    # Any empty sequence. For example, '', (), [].
    # Any empty mapping. For example, {}.

condition = False

if condition:
    print('Evaluated to True')
else:
    print('Evaluated to False')
# Out:
# Evaluated to False

# %%
condition = None

if condition:
    print('Evaluated to True')
else:
    print('Evaluated to False')
# Out:
# Evaluated to False

# %%
condition = 0

if condition:
    print('Evaluated to True')
else:
    print('Evaluated to False')
# Out:
# Evaluated to False

# %%
condition = 2

if condition:
    print('Evaluated to True')
else:
    print('Evaluated to False')
# Out:
# Evaluated to True

# %%
condition = []
if condition:
    print('Evaluated to True')
else:
    print('Evaluated to False')
# Out:
# Evaluated to False

# %%
condition = {}

if condition:
    print('Evaluated to True')
else:
    print('Evaluated to False')
# Out:
# Evaluated to False

# %%
condition = 'Test'

if condition:
    print('Evaluated to True')
else:
    print('Evaluated to False')
# Out:
# Evaluated to True
